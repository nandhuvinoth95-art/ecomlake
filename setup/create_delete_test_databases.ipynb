# %%
# %sql
CREATE CATALOG IF NOT EXISTS ecomstore;
USE CATALOG ecomstore;
--DROP CATALOG IF EXISTS ecomlake CASCADE

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ecomstore.ecomlake;
-- DROP SCHEMA IF EXISTS ecomlake.landing CASCADE;

# %%
# %sql
-- 1. Ensure you are using your new Catalog and Schema
USE CATALOG ecomstore;
USE SCHEMA ecomlake;
-- Note: You DO NOT need to create 'delta/bronze' folders anymore!
-- When you ingest data, you will simply write it to tables like:
-- ecomstore.ecomlake.bronze_orders

# %%
# batch 1 data remove
dbutils.fs.rm("s3://ecom-landing-zone-2026/checkpoints/", True)
dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/", True)

# %%
# batch 2 data remove
dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/customers/customers_2026_03_04.csv", True)
dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/customers/customers_2026_03_05.csv", True)

dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/inventory/inventory_2026_03_04.csv", True)
dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/inventory/inventory_2026_03_05.csv", True)
dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/inventory/inventory_2026_03_06.csv", True)

dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/order_items/order_items_2026_03_04.csv", True)
dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/order_items/order_items_2026_03_05.csv", True)
dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/order_items/order_items_2026_03_06.csv", True)

dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/orders/orders_2026_03_04.csv", True)
dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/orders/orders_2026_03_05.csv", True)
dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/orders/orders_2026_03_06.csv", True)

dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/payments/payments_2026_03_04.csv", True)
dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/payments/payments_2026_03_05.csv", True)
dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/payments/payments_2026_03_06.csv", True)

dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/products/products_2026_03_04.csv", True)

dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/returns/returns_2026_03_04.csv", True)
dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/returns/returns_2026_03_05.csv", True)
dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/returns/returns_2026_03_06.csv", True)

dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/sellers/sellers_2026_03_04.csv", True)

dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/shipments/shipments_2026_03_04.csv", True)
dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/shipments/shipments_2026_03_05.csv", True)
dbutils.fs.rm("s3://ecom-landing-zone-2026/landing/shipments/shipments_2026_03_06.csv", True)

# %%
# delta bronze table data drop
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.bronze_customers")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.bronze_orders")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.bronze_order_items")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.bronze_products")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.bronze_inventory")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.bronze_shipments")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.bronze_sellers")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.bronze_payments")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.bronze_returns")

# %%
# delta silver table data drop
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.silver_customers_scd")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.silver_orders")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.silver_order_items")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.silver_products")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.silver_inventory")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.silver_shipments")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.silver_sellers_scd")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.silver_payments")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.silver_returns")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.silver_quarantine_inventory")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.silver_quarantine_orders")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.silver_quarantine_products")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.silver_quarantine_sellers")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.silver_quarantine_shipments")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.silver_quarantine_payments")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.silver_quarantine_returns")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.silver_quarantine_order_items")

# %%
# delta gold table data drop
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.gold_customer_lifetime_value")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.gold_daily_sales_summary")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.gold_delivery_sla_report")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.gold_dq_log")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.gold_inventory_health")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.gold_product_returns_trend")
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.gold_seller_performance")

# %%
# delta temp table data drop if job run fails 
spark.sql("DROP TABLE IF EXISTS ecomstore.ecomlake.temp_order_items")
